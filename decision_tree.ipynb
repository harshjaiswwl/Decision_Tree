# %%
import pandas as pd

# %%
data=pd.read_csv('salary.csv')

# %%
data.head()
# Out:
#   company                 job    degree  salary
# 0  google      salesexecutive  bachelor       0
# 1  google      salesexecutive    master       0
# 2  google     businessmanager  bachelor       1
# 3  google     businessmanager    master       1
# 4  google  computerprogrammer  bachelor       0

# %%
from sklearn.preprocessing import LabelEncoder

# %%
LE=LabelEncoder()

# %%
data.head()
# Out:
#   company                 job    degree  salary
# 0  google      salesexecutive  bachelor       0
# 1  google      salesexecutive    master       0
# 2  google     businessmanager  bachelor       1
# 3  google     businessmanager    master       1
# 4  google  computerprogrammer  bachelor       0

# %%
x=data[['company','job','degree']]

# %%
y=data[['salary']]

# %%
data["company"]=LE.fit_transform(data["company"])
data["degree"]=LE.fit_transform(data["degree"])
data["job"]=LE.fit_transform(data["job"])

# %%
data
# Out:
#     company  job  degree  salary
# 0         2    2       0       0
# 1         2    2       1       0
# 2         2    0       0       1
# 3         2    0       1       1
# 4         2    1       0       0
# 5         2    1       1       1
# 6         0    2       0       0
# 7         0    0       0       0
# 8         0    0       1       0
# 9         0    2       1       1
# 10        1    2       0       1
# 11        1    0       0       1
# 12        1    0       1       1
# 13        1    2       0       1
# 14        1    2       1       1
# 15        1    0       0       1
# 16        1    0       0       1
# 17        1    1       1       1

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model=DecisionTreeClassifier()

# %%
model.fit(x,y)
# Out:
# DecisionTreeClassifier()

# %%
model.predict([[1,2,1]])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1], dtype=int64)

# %%
import matplotlib.pyplot as plt
% matplotlib inline
# Out:
# UsageError: Line magic function `%` not found.

# %%
from sklearn import tree

# %%
tree.plot_tree(model,filled=True)
# Out:
# [Text(0.36363636363636365, 0.9166666666666666, 'X[0] <= 0.5\ngini = 0.444\nsamples = 18\nvalue = [6, 12]'),
#  Text(0.18181818181818182, 0.75, 'X[2] <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.09090909090909091, 0.5833333333333334, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.2727272727272727, 0.5833333333333334, 'X[1] <= 1.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.18181818181818182, 0.4166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.36363636363636365, 0.4166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5454545454545454, 0.75, 'X[0] <= 1.5\ngini = 0.337\nsamples = 14\nvalue = [3, 11]'),
#  Text(0.45454545454545453, 0.5833333333333334, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.6363636363636364, 0.5833333333333334, 'X[1] <= 0.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.5454545454545454, 0.4166666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.7272727272727273, 0.4166666666666667, 'X[2] <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.6363636363636364, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.8181818181818182, 0.25, 'X[1] <= 1.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.7272727272727273, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9090909090909091, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]')]

# %% [markdown]
# # using test_train

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=model.predict(x_test)

# %%
y_pred
# Out:
# array([1, 1, 1, 1, 0, 0], dtype=int64)

# %%
from sklearn.metrics import accuracy_score

# %%
score=accuracy_score(y_pred,y_test)

# %%
score
# Out:
# 0.8333333333333334

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_pred,y_test)
# Out:
# 0.16666666666666666

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf=RandomForestClassifier(n_estimators=20)

# %%
rf.fit(x_train,y_train)
# Out:
# C:\Users\shivesh\AppData\Local\Temp\ipykernel_5004\1149647727.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(x_train,y_train)
# RandomForestClassifier(n_estimators=20)

# %%
rf.estimators_
# Out:
# [DecisionTreeClassifier(max_features='auto', random_state=451618376),
#  DecisionTreeClassifier(max_features='auto', random_state=1619048467),
#  DecisionTreeClassifier(max_features='auto', random_state=830639839),
#  DecisionTreeClassifier(max_features='auto', random_state=1429243396),
#  DecisionTreeClassifier(max_features='auto', random_state=308617065),
#  DecisionTreeClassifier(max_features='auto', random_state=2123458583),
#  DecisionTreeClassifier(max_features='auto', random_state=496310285),
#  DecisionTreeClassifier(max_features='auto', random_state=737880505),
#  DecisionTreeClassifier(max_features='auto', random_state=134765588),
#  DecisionTreeClassifier(max_features='auto', random_state=1189545661),
#  DecisionTreeClassifier(max_features='auto', random_state=109216642),
#  DecisionTreeClassifier(max_features='auto', random_state=6119229),
#  DecisionTreeClassifier(max_features='auto', random_state=438601520),
#  DecisionTreeClassifier(max_features='auto', random_state=253675750),
#  DecisionTreeClassifier(max_features='auto', random_state=59634380),
#  DecisionTreeClassifier(max_features='auto', random_state=1122413290),
#  DecisionTreeClassifier(max_features='auto', random_state=1541687919),
#  DecisionTreeClassifier(max_features='auto', random_state=1089133958),
#  DecisionTreeClassifier(max_features='auto', random_state=593596738),
#  DecisionTreeClassifier(max_features='auto', random_state=2032996477)]

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
from sklearn import tree

# %%
tree.plot_tree(rf.estimators_[1],filled=True)
# Out:
# [Text(0.6, 0.875, 'X[2] <= 0.5\ngini = 0.444\nsamples = 6\nvalue = [4, 8]'),
#  Text(0.4, 0.625, 'X[1] <= 1.5\ngini = 0.32\nsamples = 3\nvalue = [4, 1]'),
#  Text(0.2, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [2, 0]'),
#  Text(0.6, 0.375, 'X[0] <= 0.5\ngini = 0.444\nsamples = 2\nvalue = [2, 1]'),
#  Text(0.4, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [2, 0]'),
#  Text(0.8, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8, 0.625, 'gini = 0.0\nsamples = 3\nvalue = [0, 7]')]

# %%
tree.plot_tree(rf.estimators_[2],filled=True)
# Out:
# [Text(0.5, 0.8333333333333334, 'X[2] <= 0.5\ngini = 0.5\nsamples = 6\nvalue = [6, 6]'),
#  Text(0.25, 0.5, 'X[0] <= 0.5\ngini = 0.5\nsamples = 4\nvalue = [5, 5]'),
#  Text(0.125, 0.16666666666666666, 'gini = 0.0\nsamples = 2\nvalue = [5, 0]'),
#  Text(0.375, 0.16666666666666666, 'gini = 0.0\nsamples = 2\nvalue = [0, 5]'),
#  Text(0.75, 0.5, 'X[0] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.625, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.875, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]')]

# %%
tree.plot_tree(rf.estimators_[0],filled=True)
# Out:
# [Text(0.5, 0.8333333333333334, 'X[1] <= 1.0\ngini = 0.486\nsamples = 8\nvalue = [5, 7]'),
#  Text(0.25, 0.5, 'X[0] <= 0.5\ngini = 0.494\nsamples = 5\nvalue = [4, 5]'),
#  Text(0.125, 0.16666666666666666, 'gini = 0.0\nsamples = 2\nvalue = [4, 0]'),
#  Text(0.375, 0.16666666666666666, 'gini = 0.0\nsamples = 3\nvalue = [0, 5]'),
#  Text(0.75, 0.5, 'X[0] <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.625, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.875, 0.16666666666666666, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]')]

# %%
tree.plot_tree(rf.estimators_[3],filled=True)
# Out:
# [Text(0.5, 0.875, 'X[2] <= 0.5\ngini = 0.486\nsamples = 9\nvalue = [5, 7]'),
#  Text(0.25, 0.625, 'X[1] <= 0.5\ngini = 0.49\nsamples = 4\nvalue = [4, 3]'),
#  Text(0.125, 0.375, 'gini = 0.0\nsamples = 2\nvalue = [0, 3]'),
#  Text(0.375, 0.375, 'gini = 0.0\nsamples = 2\nvalue = [4, 0]'),
#  Text(0.75, 0.625, 'X[1] <= 0.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.625, 0.375, 'X[0] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.5, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.75, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.875, 0.375, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]')]

# %%
tree.plot_tree(rf.estimators_[4],filled=True)
# Out:
# [Text(0.42857142857142855, 0.9, 'X[1] <= 0.5\ngini = 0.444\nsamples = 10\nvalue = [4, 8]'),
#  Text(0.21428571428571427, 0.7, 'X[2] <= 0.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.14285714285714285, 0.5, 'X[0] <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.07142857142857142, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.21428571428571427, 0.3, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.2857142857142857, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6428571428571429, 0.7, 'X[1] <= 1.5\ngini = 0.375\nsamples = 6\nvalue = [2, 6]'),
#  Text(0.42857142857142855, 0.5, 'X[0] <= 1.5\ngini = 0.375\nsamples = 3\nvalue = [1, 3]'),
#  Text(0.35714285714285715, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 2]'),
#  Text(0.5, 0.3, 'X[2] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.42857142857142855, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5714285714285714, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8571428571428571, 0.5, 'X[2] <= 0.5\ngini = 0.375\nsamples = 3\nvalue = [1, 3]'),
#  Text(0.7857142857142857, 0.3, 'X[0] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.7142857142857143, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8571428571428571, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9285714285714286, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 2]')]

# %%
tree.plot_tree(rf.estimators_[5],filled=True)
# Out:
# [Text(0.5, 0.9, 'X[2] <= 0.5\ngini = 0.375\nsamples = 8\nvalue = [3, 9]'),
#  Text(0.25, 0.7, 'X[1] <= 0.5\ngini = 0.346\nsamples = 5\nvalue = [2, 7]'),
#  Text(0.125, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 5]'),
#  Text(0.375, 0.5, 'X[0] <= 0.5\ngini = 0.5\nsamples = 3\nvalue = [2, 2]'),
#  Text(0.25, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5, 0.3, 'X[1] <= 1.5\ngini = 0.444\nsamples = 2\nvalue = [1, 2]'),
#  Text(0.375, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.625, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 2]'),
#  Text(0.75, 0.7, 'X[1] <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.625, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.875, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]')]

# %%
tree.plot_tree(rf.estimators_[6],filled=True)
# Out:
# [Text(0.3333333333333333, 0.875, 'X[0] <= 0.5\ngini = 0.444\nsamples = 8\nvalue = [4, 8]'),
#  Text(0.16666666666666666, 0.625, 'gini = 0.0\nsamples = 2\nvalue = [3, 0]'),
#  Text(0.5, 0.625, 'X[0] <= 1.5\ngini = 0.198\nsamples = 6\nvalue = [1, 8]'),
#  Text(0.3333333333333333, 0.375, 'gini = 0.0\nsamples = 4\nvalue = [0, 6]'),
#  Text(0.6666666666666666, 0.375, 'X[2] <= 0.5\ngini = 0.444\nsamples = 2\nvalue = [1, 2]'),
#  Text(0.5, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8333333333333334, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 2]')]

# %%
tree.plot_tree(rf.estimators_[7],filled=True)
# Out:
# [Text(0.6666666666666666, 0.875, 'X[2] <= 0.5\ngini = 0.5\nsamples = 7\nvalue = [6, 6]'),
#  Text(0.5, 0.625, 'X[1] <= 0.5\ngini = 0.375\nsamples = 5\nvalue = [6, 2]'),
#  Text(0.3333333333333333, 0.375, 'X[0] <= 0.5\ngini = 0.48\nsamples = 3\nvalue = [3, 2]'),
#  Text(0.16666666666666666, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [3, 0]'),
#  Text(0.5, 0.125, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6666666666666666, 0.375, 'gini = 0.0\nsamples = 2\nvalue = [3, 0]'),
#  Text(0.8333333333333334, 0.625, 'gini = 0.0\nsamples = 2\nvalue = [0, 4]')]

# %%
tree.plot_tree(rf.estimators_[8],filled=True)
# Out:
# [Text(0.5, 0.875, 'X[0] <= 0.5\ngini = 0.486\nsamples = 9\nvalue = [5, 7]'),
#  Text(0.25, 0.625, 'X[1] <= 1.0\ngini = 0.32\nsamples = 3\nvalue = [4, 1]'),
#  Text(0.125, 0.375, 'gini = 0.0\nsamples = 2\nvalue = [4, 0]'),
#  Text(0.375, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.75, 0.625, 'X[2] <= 0.5\ngini = 0.245\nsamples = 6\nvalue = [1, 6]'),
#  Text(0.625, 0.375, 'X[1] <= 0.5\ngini = 0.375\nsamples = 3\nvalue = [1, 3]'),
#  Text(0.5, 0.125, 'gini = 0.0\nsamples = 2\nvalue = [0, 3]'),
#  Text(0.75, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.875, 0.375, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]')]

# %%
tree.plot_tree(rf.estimators_[9],filled=True)
# Out:
# [Text(0.5, 0.9, 'X[1] <= 0.5\ngini = 0.375\nsamples = 9\nvalue = [3, 9]'),
#  Text(0.25, 0.7, 'X[0] <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.125, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.375, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.75, 0.7, 'X[2] <= 0.5\ngini = 0.346\nsamples = 6\nvalue = [2, 7]'),
#  Text(0.625, 0.5, 'X[0] <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.5, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.75, 0.3, 'X[0] <= 1.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.625, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.875, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.875, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [0, 6]')]

# %%
tree.plot_tree(rf.estimators_[10],filled=True)
# Out:
# [Text(0.5, 0.875, 'X[1] <= 0.5\ngini = 0.444\nsamples = 7\nvalue = [4, 8]'),
#  Text(0.25, 0.625, 'X[2] <= 0.5\ngini = 0.49\nsamples = 3\nvalue = [3, 4]'),
#  Text(0.125, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.375, 0.375, 'X[0] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [3, 3]'),
#  Text(0.25, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [3, 0]'),
#  Text(0.5, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 3]'),
#  Text(0.75, 0.625, 'X[2] <= 0.5\ngini = 0.32\nsamples = 4\nvalue = [1, 4]'),
#  Text(0.625, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.875, 0.375, 'gini = 0.0\nsamples = 3\nvalue = [0, 4]')]

# %%
tree.plot_tree(rf.estimators_[11],filled=True)
# Out:
# [Text(0.5, 0.9, 'X[1] <= 1.5\ngini = 0.444\nsamples = 11\nvalue = [4, 8]'),
#  Text(0.2, 0.7, 'X[0] <= 0.5\ngini = 0.469\nsamples = 7\nvalue = [3, 5]'),
#  Text(0.1, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.3, 0.5, 'X[0] <= 1.5\ngini = 0.278\nsamples = 5\nvalue = [1, 5]'),
#  Text(0.2, 0.3, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.4, 0.3, 'X[2] <= 0.5\ngini = 0.444\nsamples = 2\nvalue = [1, 2]'),
#  Text(0.3, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 2]'),
#  Text(0.8, 0.7, 'X[0] <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.7, 0.5, 'X[2] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]')]

# %%
tree.plot_tree(rf.estimators_[12],filled=True)
# Out:
# [Text(0.4, 0.9, 'X[1] <= 0.5\ngini = 0.486\nsamples = 7\nvalue = [5, 7]'),
#  Text(0.2, 0.7, 'X[0] <= 0.5\ngini = 0.408\nsamples = 3\nvalue = [2, 5]'),
#  Text(0.1, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [2, 0]'),
#  Text(0.3, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 5]'),
#  Text(0.6, 0.7, 'X[0] <= 0.5\ngini = 0.48\nsamples = 4\nvalue = [3, 2]'),
#  Text(0.5, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7, 0.5, 'X[0] <= 1.5\ngini = 0.5\nsamples = 3\nvalue = [2, 2]'),
#  Text(0.6, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8, 0.3, 'X[2] <= 0.5\ngini = 0.444\nsamples = 2\nvalue = [2, 1]'),
#  Text(0.7, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [2, 0]'),
#  Text(0.9, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]')]

# %%
tree.plot_tree(rf.estimators_[18],filled=True)
# Out:
# [Text(0.5, 0.9, 'X[2] <= 0.5\ngini = 0.5\nsamples = 9\nvalue = [6, 6]'),
#  Text(0.2, 0.7, 'X[0] <= 0.5\ngini = 0.444\nsamples = 5\nvalue = [4, 2]'),
#  Text(0.1, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [3, 0]'),
#  Text(0.3, 0.5, 'X[1] <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.2, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4, 0.3, 'X[1] <= 1.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.3, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8, 0.7, 'X[1] <= 0.5\ngini = 0.444\nsamples = 4\nvalue = [2, 4]'),
#  Text(0.7, 0.5, 'X[0] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [2, 2]'),
#  Text(0.6, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [2, 0]'),
#  Text(0.8, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 2]'),
#  Text(0.9, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]')]
